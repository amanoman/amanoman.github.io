# %% [markdown]
# # PART3 特徴量を作ってみよう

# %% [markdown]
# ## おまじない

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression as LR

# %% [markdown]
# ## データの読み込み
# - train.csvとtest.csvとsample.csvの３つのファイルを読み込みましょう
# - それぞれを読み込んだものは変数はtrain, test, sampleに代入しましょう
# - sampleを読み込む時は、header=Noneというオプションを忘れないようにしましょう

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
sample = pd.read_csv("sample.csv",header = None)

# %% [markdown]
# ## yの折れ線グラフを描いてみましょう

# %%
train["y"].plot(figsize=(12,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## trainの先頭行を表示してみよう

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %% [markdown]
# ## trainのdatetimeから年と月のデータを取り出し、trainの新たなカラムとして追加しましょう
# - apply関数とsplit関数を使います
# - 年の新しいカラム名はyearとし、月の新しいカラム名はmonthとしましょう

# %%
train["year"] = train["datetime"].apply(lambda x : x.split("-")[0])
train["month"] = train["datetime"].apply(lambda x : x.split("-")[1])

# %% [markdown]
# ## trainの中身を確認してみましょう

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature  year month
# 0      快晴            --         19.8  2013    11
# 1      快晴            --         17.0  2013    11
# 2      快晴            --         15.5  2013    11
# 3      快晴            --         15.2  2013    11
# 4      快晴            --         16.1  2013    11

# %% [markdown]
# ## 同様にtestもdatetimeから年と月のデータを取り出し、testの新たなカラムとして追加しましょう

# %%
test["year"] = test["datetime"].apply(lambda x : x.split("-")[0])
test["month"] = test["datetime"].apply(lambda x : x.split("-")[1])

# %% [markdown]
# ## trainのデータの型を確認してみましょう

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datetime       207 non-null    object
#  1   y              207 non-null    int64
#  2   week           207 non-null    object
#  3   soldout        207 non-null    int64
#  4   name           207 non-null    object
#  5   kcal           166 non-null    float64
#  6   remarks        21 non-null     object
#  7   event          14 non-null     object
#  8   payday         10 non-null     float64
#  9   weather        207 non-null    object
#  10  precipitation  207 non-null    object
#  11  temperature    207 non-null    float64
#  12  year           207 non-null    object
#  13  month          207 non-null    object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 22.8+ KB

# %% [markdown]
# ## train,testのデータの型を整数（int）に変換しましょう
# - データの型を変換したい場合は、astype関数を使います
# - オプションにはデータの型を入れます。今回は整数に変換したい為、np.intと書きます
# - 変換したものは、もとのカラムに代入しなおしましょう

# %%
train["year"] = train["year"].astype(np.int)
train["month"] = train["month"].astype(np.int)
test["year"] = test["year"].astype(np.int)
test["month"] = test["month"].astype(np.int)

# %% [markdown]
# ## train,testからyearとmonthを取り出し、変数trainX,testXに代入しましょう

# %%
trainX = train[["year","month"]]
testX = test[["year","month"]]

# %% [markdown]
# ## trainXの中身を確認してみましょう

# %%
trainX.head()
# Out:
#    year  month
# 0  2013     11
# 1  2013     11
# 2  2013     11
# 3  2013     11
# 4  2013     11

# %% [markdown]
# ## trainからyを取り出し、変数yに代入しましょう

# %%
y = train["y"]

# %% [markdown]
# ## 回帰モデルの箱を用意しましょう
# - 変数名はmodel1としましょう

# %%
model1 = LR()

# %% [markdown]
# ## 重回帰モデルを作りましょう

# %%
model1.fit(trainX,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## 作ったモデルの傾きや切片を確かめてみましょう

# %%
model1.coef_
# Out:
# array([-104.0107109 ,   -7.41004428])

# %%
model1.intercept_
# Out:
# 209594.15656370917

# %% [markdown]
# ## testXを使って予測をし、予測結果を変数predに代入しましょう

# %%
pred = model1.predict(testX)

# %% [markdown]
# ## sample[1]に予測結果を代入しましょう

# %%
sample[1] = pred

# %%
sample.tail()
# Out:
#              0          1
# 35  2014-11-21  35.074318
# 36  2014-11-25  35.074318
# 37  2014-11-26  35.074318
# 38  2014-11-27  35.074318
# 39  2014-11-28  35.074318

# %% [markdown]
# ## sampleを"submit4.csv"というファイルで出力して、DeepAnalyticsに投稿しましょう

# %%
sample.to_csv("submit4.csv",index=None,header=None)

# %% [markdown]
# ## 追加する特徴量検討の為に、trainXに対する予測値を変数predに代入しましょう
# - trainXに対して予測を行えば、実際の売り上げyがわかっているので、その差を比較することができます
# - そこでtrainXに対する予測値と、実際の売り上げyとを引き算することで、どの日が大きく予測を外していたかを確認します
# - 大きく外れていたものから共通する要素が見つけられれば、その要素を加えることで更に精度が良いモデルを作れる可能性があります
# - その準備として、まずmodel1とtrainXを使って、trainXに対する予測値を求めましょう

# %%
pred = model1.predict(trainX)

# %% [markdown]
# ## predをtrainの新たなカラムpredとして代入しましょう

# %%
train["pred"] = pred

# %% [markdown]
# ## trainのyとpredを引き算した結果をtrainの新たなカラムresとして代入しましょう
# - yとpredを引き算する為には、単純にtrain["y"] - train["pred"]と書きます

# %%
train["res"] = train["y"]-train["pred"]

# %% [markdown]
# ## trainのresでソートして中身を確認しましょう
# - 今回はhead関数を使わず、表示しましょう

# %%
train.sort_values(by="res")
# Out:
#        datetime    y week  soldout         name   kcal   remarks event  \
# 27   2013-12-26   80    木        0           酢豚    NaN       NaN   NaN
# 0    2013-11-18   90    月        0     厚切りイカフライ    NaN       NaN   NaN
# 81    2014-3-26   51    水        0  肉団子クリームシチュー  392.0       NaN   NaN
# 82    2014-3-27   55    木        1     ロース甘味噌焼き  315.0       NaN   NaN
# 1    2013-11-19  101    火        1      手作りヒレカツ    NaN       NaN   NaN
# ..          ...  ...  ...      ...          ...    ...       ...   ...
# 115   2014-5-16  126    金        0       ポークカレー    NaN  お楽しみメニュー  ママの会
# 135   2014-6-13  121    金        0       キーマカレー    NaN  お楽しみメニュー   NaN
# 155   2014-7-11  124    金        0       ポークカレー    NaN  お楽しみメニュー   NaN
# 196   2014-9-12  115    金        0       ポークカレー    NaN  お楽しみメニュー   NaN
# 174    2014-8-8  129    金        0       チキンカレー    NaN  お楽しみメニュー   NaN
#
#      payday weather precipitation  temperature  year  month        pred  \
# 27      NaN       曇            --          7.3  2013     12  131.674984
# 0       NaN      快晴            --         19.8  2013     11  139.085028
# 81      NaN       曇            --         18.7  2014      3   94.354672
# 82      NaN       曇           1.5         12.4  2014      3   94.354672
# 1       NaN      快晴            --         17.0  2013     11  139.085028
# ..      ...     ...           ...          ...   ...    ...         ...
# 115     NaN      快晴            --         23.8  2014      5   79.534583
# 135     NaN      晴れ            --         29.5  2014      6   72.124539
# 155     NaN      晴れ            --         33.9  2014      7   64.714495
# 196     NaN      晴れ            --         27.3  2014      9   49.894406
# 174     1.0       曇            --         31.1  2014      8   57.304450
#
#            res
# 27  -51.674984
# 0   -49.085028
# 81  -43.354672
# 82  -39.354672
# 1   -38.085028
# ..         ...
# 115  46.465417
# 135  48.875461
# 155  59.285505
# 196  65.105594
# 174  71.695550
#
# [207 rows x 16 columns]

# %% [markdown]
# ## 値が「お楽しみメニュー」であれば１、そうでなければ0とする自作関数を作りましょう
# - 自作の関数を作る為には、defを使います

# %%
def jisaku1(x):
    if x == "お楽しみメニュー":
        return 1
    else:
        return 0

# %% [markdown]
# ## jisaku1関数とapply関数を使って、trainとtestの新たなカラムfunを作りましょう

# %%
train["fun"] = train["remarks"].apply(lambda x :jisaku1(x))
test["fun"] = test["remarks"].apply(lambda x :jisaku1(x))

# %% [markdown]
# ## trainの中身を確認してみましょう

# %%
train
# Out:
#        datetime    y week  soldout          name   kcal          remarks  \
# 0    2013-11-18   90    月        0      厚切りイカフライ    NaN              NaN
# 1    2013-11-19  101    火        1       手作りヒレカツ    NaN              NaN
# 2    2013-11-20  118    水        0    白身魚唐揚げ野菜あん    NaN              NaN
# 3    2013-11-21  120    木        1        若鶏ピリ辛焼    NaN              NaN
# 4    2013-11-22  130    金        1      ビッグメンチカツ    NaN              NaN
# ..          ...  ...  ...      ...           ...    ...              ...
# 202   2014-9-24   59    水        1   白身魚のマスタード焼き  408.0              NaN
# 203   2014-9-25   50    木        0       牛カルビ焼き肉  394.0              NaN
# 204   2014-9-26   45    金        0      ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205   2014-9-29   56    月        1      豚肉と玉子の炒め  404.0              NaN
# 206   2014-9-30   40    火        0  鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature  year  month  \
# 0              NaN     NaN      快晴            --         19.8  2013     11
# 1              NaN     NaN      快晴            --         17.0  2013     11
# 2              NaN     NaN      快晴            --         15.5  2013     11
# 3              NaN     NaN      快晴            --         15.2  2013     11
# 4              NaN     NaN      快晴            --         16.1  2013     11
# ..             ...     ...     ...           ...          ...   ...    ...
# 202            NaN     NaN       曇             0         24.8  2014      9
# 203            NaN     NaN       曇             0         25.4  2014      9
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1  2014      9
# 205            NaN     NaN      快晴            --         26.6  2014      9
# 206            NaN     NaN      快晴            --         28.1  2014      9
#
#            pred        res  fun
# 0    139.085028 -49.085028    0
# 1    139.085028 -38.085028    0
# 2    139.085028 -21.085028    0
# 3    139.085028 -19.085028    0
# 4    139.085028  -9.085028    0
# ..          ...        ...  ...
# 202   49.894406   9.105594    0
# 203   49.894406   0.105594    0
# 204   49.894406  -4.894406    0
# 205   49.894406   6.105594    0
# 206   49.894406  -9.894406    0
#
# [207 rows x 17 columns]

# %% [markdown]
# ## train,testからyearとmonth、funとtemperatureの4カラムを取り出し、変数trainX,testXに代入しましょう

# %%
trainX = train[["year","month","fun","temperature"]]
testX = test[["year","month","fun","temperature"]]

# %%
trainX.head()
# Out:
#    year  month  fun  temperature
# 0  2013     11    0         19.8
# 1  2013     11    0         17.0
# 2  2013     11    0         15.5
# 3  2013     11    0         15.2
# 4  2013     11    0         16.1

# %%
testX.head()
# Out:
#    year  month  fun  temperature
# 0  2014     10    0         20.2
# 1  2014     10    0         23.9
# 2  2014     10    0         28.7
# 3  2014     10    0         21.5
# 4  2014     10    0         22.1

# %% [markdown]
# ## 回帰モデルの箱を用意しましょう
# - 変数名はmodel2としましょう

# %%
model2 = LR()

# %% [markdown]
# ## 重回帰モデルを作りましょう

# %%
model2.fit(trainX,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## 作ったモデルの傾きや切片を確かめてみましょう

# %%
model2.coef_
# Out:
# array([-76.3765687 ,  -4.20489757,  44.63348171,  -1.25463854])

# %%
model2.intercept_
# Out:
# 153945.2541175833

# %% [markdown]
# ## testXを使って予測をし、予測結果を変数pred2に代入しましょう

# %%
pred2 = model2.predict(testX)

# %% [markdown]
# ## sample[1]に予測結果を代入しましょう

# %%
sample[1] = pred2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-136a8f8ff4b0> in <module>
#       1 sample[1] = pred2
# ----> 2 pred2.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %% [markdown]
# ## sampleを"submit5.csv"というファイルで出力して、DeepAnalyticsに投稿しましょう

# %%
sample.to_csv("submit5.csv",index=None,header=None)

# %% [markdown]
# # もう１段階予測精度を上げる

# %%
train
# Out:
#        datetime    y week  soldout          name   kcal          remarks  \
# 0    2013-11-18   90    月        0      厚切りイカフライ    NaN              NaN
# 1    2013-11-19  101    火        1       手作りヒレカツ    NaN              NaN
# 2    2013-11-20  118    水        0    白身魚唐揚げ野菜あん    NaN              NaN
# 3    2013-11-21  120    木        1        若鶏ピリ辛焼    NaN              NaN
# 4    2013-11-22  130    金        1      ビッグメンチカツ    NaN              NaN
# ..          ...  ...  ...      ...           ...    ...              ...
# 202   2014-9-24   59    水        1   白身魚のマスタード焼き  408.0              NaN
# 203   2014-9-25   50    木        0       牛カルビ焼き肉  394.0              NaN
# 204   2014-9-26   45    金        0      ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205   2014-9-29   56    月        1      豚肉と玉子の炒め  404.0              NaN
# 206   2014-9-30   40    火        0  鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature  year  month  \
# 0              NaN     NaN      快晴            --         19.8  2013     11
# 1              NaN     NaN      快晴            --         17.0  2013     11
# 2              NaN     NaN      快晴            --         15.5  2013     11
# 3              NaN     NaN      快晴            --         15.2  2013     11
# 4              NaN     NaN      快晴            --         16.1  2013     11
# ..             ...     ...     ...           ...          ...   ...    ...
# 202            NaN     NaN       曇             0         24.8  2014      9
# 203            NaN     NaN       曇             0         25.4  2014      9
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1  2014      9
# 205            NaN     NaN      快晴            --         26.6  2014      9
# 206            NaN     NaN      快晴            --         28.1  2014      9
#
#            pred        res  fun
# 0    139.085028 -49.085028    0
# 1    139.085028 -38.085028    0
# 2    139.085028 -21.085028    0
# 3    139.085028 -19.085028    0
# 4    139.085028  -9.085028    0
# ..          ...        ...  ...
# 202   49.894406   9.105594    0
# 203   49.894406   0.105594    0
# 204   49.894406  -4.894406    0
# 205   49.894406   6.105594    0
# 206   49.894406  -9.894406    0
#
# [207 rows x 17 columns]

# %%
def curry(x):
    if x.find("カレー") >=0:
        return 1
    else:
        return 0

# %%
train["curry"] = train["name"].apply(lambda x : curry(x))
test["curry"] = test["name"].apply(lambda x : curry(x))

# %%
curry_menu = train[train["curry"]==1]

# %%
train[train["curry"]==1]["y"].plot(figsize=(15,4))
# Out:
# <AxesSubplot:>

# %%
model3=LR()

# %%
trainX = train[["year","month","temperature","curry"]]
testX = test[{"year","month","temperature","curry"}]

# %%
model3.fit(trainX,y)
# Out:
# LinearRegression()

# %%
model3.coef_
# Out:
# array([-79.49025261,  -4.33285296,  -0.96457074,  32.29203676])

# %%
model3.intercept_
# Out:
# 160210.90366205774

# %%
pred3 = model3.predict(testX)

# %%
sample[1] = pred3

# %%
sample.to_csv("submit6.csv",index=None,header=None)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datetime       207 non-null    object
#  1   y              207 non-null    int64
#  2   week           207 non-null    object
#  3   soldout        207 non-null    int64
#  4   name           207 non-null    object
#  5   kcal           166 non-null    float64
#  6   remarks        21 non-null     object
#  7   event          14 non-null     object
#  8   payday         10 non-null     float64
#  9   weather        207 non-null    object
#  10  precipitation  207 non-null    object
#  11  temperature    207 non-null    float64
#  12  year           207 non-null    int32
#  13  month          207 non-null    int32
#  14  pred           207 non-null    float64
#  15  res            207 non-null    float64
#  16  fun            207 non-null    int64
#  17  curry          207 non-null    int64
# dtypes: float64(5), int32(2), int64(4), object(7)
# memory usage: 27.6+ KB

# %%
train[["curry","y"]]
# Out:
#      curry    y
# 0        0   90
# 1        0  101
# 2        0  118
# 3        0  120
# 4        0  130
# ..     ...  ...
# 202      0   59
# 203      0   50
# 204      0   45
# 205      0   56
# 206      0   40
#
# [207 rows x 2 columns]

# %%
train[train["curry"]==1]
# Out:
#       datetime    y week  soldout             name   kcal  \
# 28    2014-1-7  131    火        0     カレー入りソーセージカツ  404.0
# 38   2014-1-22  126    水        1      手作りひれかつとカレー  426.0
# 40   2014-1-24   92    金        1  鶏のレモンペッパー焼orカレー  418.0
# 46    2014-2-3  139    月        1      ハンバーグカレーソース  445.0
# 59   2014-2-21  113    金        0          酢豚orカレー  410.0
# 65    2014-3-3  131    月        0      ハンバーグカレーソース  407.0
# 72   2014-3-12   68    水        0           ビーフカレー  370.0
# 83   2014-3-28  106    金        0           キーマカレー    NaN
# 93   2014-4-11  128    金        1           チキンカレー    NaN
# 115  2014-5-16  126    金        0           ポークカレー    NaN
# 125  2014-5-30  119    金        0           チキンカレー    NaN
# 135  2014-6-13  121    金        0           キーマカレー    NaN
# 155  2014-7-11  124    金        0           ポークカレー    NaN
# 171   2014-8-5   54    火        1         鶏肉のカレー唐揚  400.0
# 174   2014-8-8  129    金        0           チキンカレー    NaN
# 183  2014-8-26   68    火        0           キーマカレー  400.0
# 196  2014-9-12  115    金        0           ポークカレー    NaN
#
#                       remarks event  payday weather precipitation  \
# 28                        NaN   NaN     NaN      快晴            --
# 38                        NaN   NaN     NaN      快晴            --
# 40   鶏のレモンペッパー焼（50食）、カレー（42食）   NaN     NaN      快晴            --
# 46                        NaN   NaN     NaN      晴れ            --
# 59           酢豚（28食）、カレー（85食）  ママの会     NaN      快晴            --
# 65                        NaN   NaN     NaN       曇            --
# 72                        NaN   NaN     NaN      快晴            --
# 83                   お楽しみメニュー   NaN     NaN      快晴            --
# 93                   お楽しみメニュー   NaN     NaN      快晴            --
# 115                  お楽しみメニュー  ママの会     NaN      快晴            --
# 125                  お楽しみメニュー   NaN     NaN      薄曇            --
# 135                  お楽しみメニュー   NaN     NaN      晴れ            --
# 155                  お楽しみメニュー   NaN     NaN      晴れ            --
# 171                       NaN   NaN     NaN      快晴            --
# 174                  お楽しみメニュー   NaN     1.0       曇            --
# 183                       NaN   NaN     NaN       雨             0
# 196                  お楽しみメニュー   NaN     NaN      晴れ            --
#
#      temperature  year  month        pred        res  fun  curry
# 28           7.3  2014      1  109.174760  21.825240    0      1
# 38           7.4  2014      1  109.174760  16.825240    0      1
# 40          10.1  2014      1  109.174760 -17.174760    0      1
# 46          15.9  2014      2  101.764716  37.235284    0      1
# 59           8.5  2014      2  101.764716  11.235284    0      1
# 65           7.8  2014      3   94.354672  36.645328    0      1
# 72          14.8  2014      3   94.354672 -26.354672    0      1
# 83          18.5  2014      3   94.354672  11.645328    1      1
# 93          16.5  2014      4   86.944628  41.055372    1      1
# 115         23.8  2014      5   79.534583  46.465417    1      1
# 125         26.9  2014      5   79.534583  39.465417    1      1
# 135         29.5  2014      6   72.124539  48.875461    1      1
# 155         33.9  2014      7   64.714495  59.285505    1      1
# 171         34.3  2014      8   57.304450  -3.304450    0      1
# 174         31.1  2014      8   57.304450  71.695550    1      1
# 183         26.2  2014      8   57.304450  10.695550    0      1
# 196         27.3  2014      9   49.894406  65.105594    1      1
