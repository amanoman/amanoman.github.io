# %%
from selenium import webdriver

# %%
browser = webdriver.Firefox()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-3-baa5adeac11b> in <module>
# ----> 1 browser = webdriver.Firefox()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     172                 command_executor=executor,
#     173                 desired_capabilities=capabilities,
# --> 174                 keep_alive=True)
#     175
#     176         # Selenium remote
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# SessionNotCreatedException: Message: Unable to find a matching set of capabilities

# %%
browser = webdriver.Chrome()

# %%
browser.get('https://scraping-for-beginner.herokuapp.com/login_page')

# %%
browser.quit()

# %%
browser = webdriver.Chrome()
browser.get('https://scraping-for-beginner.herokuapp.com/login_page')

# %%
elem_username = browser.find_element_by_id('username')

# %%
elem_username
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ae60d1ee9d257e4da268a1fb2c907ba", element="8c6f00da-2c69-4d85-a7d1-3f17e5eea9f9")>

# %%
elem_username.send_keys('imanishi')

# %%
elem_pwd = browser.find_element_by_id('password')

# %%
elem_pwd
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ae60d1ee9d257e4da268a1fb2c907ba", element="8da8a836-ecb5-4b36-8434-c3d63f8c22bc")>

# %%
elem_pwd.send_keys('kohei')

# %%
elem_login_btn = browser.find_element_by_id('login-btn')

# %%
elem_login_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ae60d1ee9d257e4da268a1fb2c907ba", element="7d12eabc-f8c9-40e5-af9a-7a7b0bc6ecdc")>

# %%
elem_login_btn.click()

# %%
elem = browser.find_element_by_id('name')

# %%
elem
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ae60d1ee9d257e4da268a1fb2c907ba", element="93ef1593-ddb5-4b5c-91d4-f6a73e5cc4f2")>

# %%
elem.text
# Out:
# '今西 航平'

# %%
elem_company = browser.find_element_by_id('company')

# %%
elem_birthday = browser.find_element_by_id('birthday')

# %%
elem_come_from = browser.find_element_by_id('come_from')

# %%
elem_hobby = browser.find_element_by_id('hobby')

# %%
elem_company.text
# Out:
# '株式会社キカガク'

# %%
elem_birthday.text
# Out:
# '1994年7月15日'

# %%
elem_hobby.text
# Out:
# 'バスケットボール\n読書\nガジェット集め'

# %%
hobby = elem_hobby.text

# %%
hobby
# Out:
# 'バスケットボール\n読書\nガジェット集め'

# %%
type(hobby)
# Out:
# str

# %%
hobby.replace('\n',',')
# Out:
# 'バスケットボール,読書,ガジェット集め'

# %%
hobby
# Out:
# 'バスケットボール\n読書\nガジェット集め'

# %%
elem_th = browser.find_element_by_tag_name('th')

# %%
elem_th.text
# Out:
# '講師名'

# %%
elems_th = browser.find_elements_by_tag_name('th')

# %%
type(elems_th)
# Out:
# list

# %%
elems_th[0].text
# Out:
# '講師名'

# %%
elems_th = browser.find_elements_by_tag_name('th')
elem_th = elems_th[3]
key = elem_th.text
key
# Out:
# '出身'

# %%
keys =[]
elems_th = browser.find_elements_by_tag_name('th')

for elem_th in elems_th:
        key = elem_th.text
        keys.append(key)

# %%
type(elems_th)
# Out:
# list

# %%
type(elem_th)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
keys
# Out:
# ['講師名', '所属企業', '生年月日', '出身', '趣味']

# %%
values = []
elems_td = browser.find_elements_by_tag_name('td')

for elem_td in elems_td:
    value = elem_td.text
    values.append(value)

# %%
values
# Out:
# ['今西 航平', '株式会社キカガク', '1994年7月15日', '千葉県', 'バスケットボール\n読書\nガジェット集め']

# %%
import pandas as pd

# %%
df =pd.DataFrame()

# %%
df['項目']= keys
df['値']= values

# %%
df
# Out:
#      項目                      値
# 0   講師名                  今西 航平
# 1  所属企業               株式会社キカガク
# 2  生年月日             1994年7月15日
# 3    出身                    千葉県
# 4    趣味  バスケットボール\n読書\nガジェット集め

# %%
df.to_csv('講師情報.csv', index=False)

# %%
from selenium import webdriver
browser = webdriver.Chrome()
browser.get('https://scraping-for-beginner.herokuapp.com/ranking/')

# %%
elem_rankingBox = browser.find_element_by_class_name('u_areaListRankingBox')

# %%
elem_title = elem_rankingBox.find_element_by_class_name('u_title').find_element_by_tag_name('h2')

# %%
title = elem_title.text
title
# Out:
# '1\n観光地 1'

# %%
title.split('\n')[1]
# Out:
# '観光地 1'

# %%
elem_rankBox= elem_rankingBox.find_element_by_class_name('u_rankBox')

# %%
elem_rankBox.text　#総合評価取得
# Out:
# '4.7'

# %%
elems_evaluateNumbers = elem_rankingBox.find_elements_by_class_name('evaluateNumber')

# %%
numbers = []
for number in elems_evaluateNumbers:
    number = number.text
    numbers.append(number)

# %%
numbers[1:5] #各評価取得
# Out:
# ['4.6', '4.5', '4.9', '4.2']

# %%
len(elems_evaluateNumbers)
# Out:
# 5

# %%
elem = browser.find_element_by_class_name('u_categoryTipsItem')

# %%
elem = elem.find_elements_by_class_name('is_rank')[0]

# %%
elem = elem.find_element_by_class_name('evaluateNumber')

# %%
elem.text
# Out:
# '4.6'

# %%
elem_rankingBox = browser.find_element_by_class_name('u_areaListRankingBox')
elem_title = elem_rankingBox.find_element_by_class_name('u_title').find_element_by_tag_name('h2')
elem_title.text
# Out:
# '1\n観光地 1'

# %%
elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')

# %%
len(elems_rankingBox)
# Out:
# 10

# %%
elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')
#すべての観光地名を格納するリストtitlesを用意
titles=[]

for elem_rankingBox in elems_rankingBox:
    #elem_rankingBox = elems_rankingBox[1]
    elem_title = elem_rankingBox.find_element_by_class_name('u_title')
    title = elem_title.text.split('\n')[1]
    titles.append(title)

# %%
titles
# Out:
# ['観光地 1',
#  '観光地 2',
#  '観光地 3',
#  '観光地 4',
#  '観光地 5',
#  '観光地 6',
#  '観光地 7',
#  '観光地 8',
#  '観光地 9',
#  '観光地 10']

# %%
elems_categoryItems = browser.find_elements_by_class_name('u_categoryTipsItem')

# %%
len(elems_categoryItems)
# Out:
# 10

# %%
elem_isrank = elems_categoryItems[0].find_elements_by_class_name('is_rank')

# %%
len(elem_isrank)
# Out:
# 4

# %%
elem_isrank[0].text
# Out:
# '4.6'

# %%
elems_rank = browser.find_elements_by_class_name('u_rankBox')
len(elems_rank)
# Out:
# 10

# %%
elems_rank[1].find_element_by_class_name('evaluateNumber').text
# Out:
# '4.7'

# %%
elems_rank = browser.find_elements_by_class_name('u_rankBox')

ranks= []
for elem_rank in elems_rank:
    elem_rank = elem_rank.find_element_by_class_name('evaluateNumber')
    rank = float(elem_rank.text)
    ranks.append(rank)

# %%
ranks #総合評価
# Out:
# [4.7, 4.7, 4.6, 4.5, 4.5, 4.4, 4.3, 4.3, 4.2, 4.1]

# %%
elems_rank = browser.find_elements_by_class_name('u_rankBox')
categories = []

for elem in elems:
    elems_rank = elem.find_elements_by_class_name('is_rank')
    _ranks = []
    for elem_rank in elems_rank:
        rank = elem_rank.find_element_by_class_name('evaluateNumber').text
        _ranks.append(rank)
    categories.append(_ranks)

# %%
categories
# Out:
# []

# %%
_ranks
# Out:
# []

# %%
items
# Out:
# []

# %%
items
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
elems = browser.find_elements_by_class_name('evaluateNumber')

# %%
type(elems)
# Out:
# list

# %%
browser  = webdriver.Chrome

# %%
elems = browser.find_elements_by_class_name('evaluateNumber')
value = []
for elem in elems:
    value.append(elem.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1860f2ae6e1e> in <module>
# ----> 1 elems = browser.find_elements_by_class_name('evaluateNumber')
#       2 value = []
#       3 for elem in elems:
#       4     value.append(elem.text)
#       5
#
# NameError: name 'browser' is not defined

# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome()
browser.get('https://scraping-for-beginner.herokuapp.com/ranking/')

# %%
elems_rank = browser.find_elements_by_class_name('u_rankBox')

# %%
len(elems_rank)
# Out:
# 10

# %%
elems_rank[1].find_element_by_class_name('evaluateNumber').text
# Out:
# '4.7'

# %%
elems_rank = browser.find_elements_by_class_name('u_rankBox')

ranks = []
for elem_rank in elems_rank:
    elem_rank.find_element_by_class_name('evaluateNumber')
    rank = float(elem_rank.text)
    ranks.append(rank)

# %%
ranks
# Out:
# [4.7, 4.7, 4.6, 4.5, 4.5, 4.4, 4.3, 4.3, 4.2, 4.1]

# %%
elems = browser.find_elements_by_class_name('u_categoryTipsItem')

# %%
len(elems)
# Out:
# 10

# %%
elem = elems[1]

# %%
elems_rank = elem.find_elements_by_class_name('is_rank')

# %%
len(elems_rank)
# Out:
# 4

# %%
categories = []
for elem in elems:
    elems_rank = elem.find_elements_by_class_name('is_rank')

    _ranks = []
    for elem_rank in elems_rank:
        rank = elem_rank.find_element_by_class_name('evaluateNumber').text
        _ranks.append(float(rank))
    categories.append(_ranks)

# %%
categories
# Out:
# [[4.6, 4.5, 4.9, 4.2],
#  [4.6, 4.5, 4.9, 4.2],
#  [4.5, 4.4, 4.8, 4.1],
#  [4.4, 4.4, 4.8, 4.0],
#  [4.4, 4.3, 4.7, 4.0],
#  [4.3, 4.3, 4.7, 3.9],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.1, 4.1, 4.5, 3.7],
#  [4.0, 4.1, 4.4, 3.6]]

# %%
elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')
#すべての観光地名を格納するリストtitlesを用意
titles=[]

for elem_rankingBox in elems_rankingBox:
    #elem_rankingBox = elems_rankingBox[1]
    elem_title = elem_rankingBox.find_element_by_class_name('u_title')
    title = elem_title.text.split('\n')[1]
    titles.append(title)

# %% [markdown]
# # Pandasの形式に変換

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df['観光地名'] = titles
df['総合評価'] = ranks

# %%
df
# Out:
#      観光地名  総合評価
# 0   観光地 1   4.7
# 1   観光地 2   4.7
# 2   観光地 3   4.6
# 3   観光地 4   4.5
# 4   観光地 5   4.5
# 5   観光地 6   4.4
# 6   観光地 7   4.3
# 7   観光地 8   4.3
# 8   観光地 9   4.2
# 9  観光地 10   4.1

# %%
df_categories = pd.DataFrame(categories)
df_categories.columns = ['楽しさ','人混みの多さ','景色','アクセス']

# %%
df_categories
# Out:
#    楽しさ  人混みの多さ   景色  アクセス
# 0  4.6     4.5  4.9   4.2
# 1  4.6     4.5  4.9   4.2
# 2  4.5     4.4  4.8   4.1
# 3  4.4     4.4  4.8   4.0
# 4  4.4     4.3  4.7   4.0
# 5  4.3     4.3  4.7   3.9
# 6  4.2     4.2  4.6   3.8
# 7  4.2     4.2  4.6   3.8
# 8  4.1     4.1  4.5   3.7
# 9  4.0     4.1  4.4   3.6

# %%
df = pd.concat([df,df_categories],axis=1)

# %%
df.to_csv('観光地情報.csv',index=False,encoding="utf-16")

# %% [markdown]
# # 全ページの情報を取得

# %%
i=3
'https://scraping-for-beginner.herokuapp.com/ranking/?page={}'.format(i)
# Out:
# 'https://scraping-for-beginner.herokuapp.com/ranking/?page=3'

# %%
titles = []
ranks = []
categories = []

for page in range(1,4):
    
    url = 'https://scraping-for-beginner.herokuapp.com/ranking/?page={}'.format(page)
    browser.get(url)

    #観光地名
    elems_rankingBox = browser.find_elements_by_class_name('u_areaListRankingBox')
    for elem_rankingBox in elems_rankingBox:
        #elem_rankingBox = elems_rankingBox[1]
        elem_title = elem_rankingBox.find_element_by_class_name('u_title')
        title = elem_title.text.split('\n')[1]
        titles.append(title)

    #総合評価
    elems_rank = browser.find_elements_by_class_name('u_rankBox')
    for elem_rank in elems_rank:
        elem_rank.find_element_by_class_name('evaluateNumber')
        rank = float(elem_rank.text)
        ranks.append(rank)

    #各項目
    elems = browser.find_elements_by_class_name('u_categoryTipsItem')
    for elem in elems:
        elems_rank = elem.find_elements_by_class_name('is_rank')
        _ranks = []
        for elem_rank in elems_rank:
            rank = elem_rank.find_element_by_class_name('evaluateNumber').text
            _ranks.append(float(rank))
        categories.append(_ranks)

# %%
titles
# Out:
# ['観光地 1',
#  '観光地 2',
#  '観光地 3',
#  '観光地 4',
#  '観光地 5',
#  '観光地 6',
#  '観光地 7',
#  '観光地 8',
#  '観光地 9',
#  '観光地 10',
#  '観光地 11',
#  '観光地 12',
#  '観光地 13',
#  '観光地 14',
#  '観光地 15',
#  '観光地 16',
#  '観光地 17',
#  '観光地 18',
#  '観光地 19',
#  '観光地 20',
#  '観光地 21',
#  '観光地 22',
#  '観光地 23',
#  '観光地 24',
#  '観光地 25',
#  '観光地 26',
#  '観光地 27',
#  '観光地 28',
#  '観光地 29',
#  '観光地 30']

# %%
ranks
# Out:
# [4.7,
#  4.7,
#  4.6,
#  4.5,
#  4.5,
#  4.4,
#  4.3,
#  4.3,
#  4.2,
#  4.1,
#  4.1,
#  4.0,
#  3.9,
#  3.9,
#  3.8,
#  3.7,
#  3.7,
#  3.6,
#  3.5,
#  3.5,
#  3.4,
#  3.3,
#  3.3,
#  3.2,
#  3.1,
#  3.1,
#  3.0,
#  2.9,
#  2.9,
#  2.8]

# %%
categories
# Out:
# [[4.6, 4.5, 4.9, 4.2],
#  [4.6, 4.5, 4.9, 4.2],
#  [4.5, 4.4, 4.8, 4.1],
#  [4.4, 4.4, 4.8, 4.0],
#  [4.4, 4.3, 4.7, 4.0],
#  [4.3, 4.3, 4.7, 3.9],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.2, 4.2, 4.6, 3.8],
#  [4.1, 4.1, 4.5, 3.7],
#  [4.0, 4.1, 4.4, 3.6],
#  [4.0, 4.0, 4.4, 3.6],
#  [3.9, 4.0, 4.3, 3.5],
#  [3.8, 3.9, 4.3, 3.4],
#  [3.8, 3.9, 4.2, 3.4],
#  [3.7, 3.8, 4.2, 3.3],
#  [3.6, 3.8, 4.1, 3.2],
#  [3.6, 3.7, 4.1, 3.2],
#  [3.5, 3.7, 4.0, 3.1],
#  [3.4, 3.6, 3.9, 3.0],
#  [3.4, 3.6, 3.9, 3.0],
#  [3.3, 3.5, 3.8, 2.9],
#  [3.2, 3.5, 3.8, 2.8],
#  [3.2, 3.4, 3.7, 2.8],
#  [3.1, 3.4, 3.7, 2.7],
#  [3.0, 3.3, 3.6, 2.6],
#  [3.0, 3.3, 3.6, 2.6],
#  [2.9, 3.2, 3.5, 2.5],
#  [2.8, 3.2, 3.4, 2.4],
#  [2.8, 3.1, 3.4, 2.4],
#  [2.7, 3.1, 3.3, 2.3]]

# %%
df
# Out:
#      観光地名  総合評価  楽しさ  人混みの多さ   景色  アクセス
# 0   観光地 1   4.7  4.6     4.5  4.9   4.2
# 1   観光地 2   4.7  4.6     4.5  4.9   4.2
# 2   観光地 3   4.6  4.5     4.4  4.8   4.1
# 3   観光地 4   4.5  4.4     4.4  4.8   4.0
# 4   観光地 5   4.5  4.4     4.3  4.7   4.0
# 5   観光地 6   4.4  4.3     4.3  4.7   3.9
# 6   観光地 7   4.3  4.2     4.2  4.6   3.8
# 7   観光地 8   4.3  4.2     4.2  4.6   3.8
# 8   観光地 9   4.2  4.1     4.1  4.5   3.7
# 9  観光地 10   4.1  4.0     4.1  4.4   3.6

# %% [markdown]
# # 画像の収集

# %% [markdown]
# # Pillowの使い方

# %%
from PIL import Image

# %%
img = Image.open('sample.JPG')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x798 at 0x1C657C32240>

# %%
img.size
# Out:
# (1200, 798)

# %% [markdown]
# ### リサイズ

# %%
img = img.resize((1024,768))

# %%
img.size
# Out:
# (1024, 768)

# %%
img.save('sample_resize.jpg')

# %%
from selenium import webdriver
browser = webdriver.Chrome()
browser.get('https://scraping-for-beginner.herokuapp.com/image')

# %%
elem = browser.find_element_by_class_name('material-placeholder')

# %%
elem =elem.find_element_by_tag_name('img')

# %%
elem
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="227d94aff56ae6eabb87b522e312bda3", element="27dd9746-61ec-4691-b6bd-fe2770d58403")>

# %%
url = elem.get_attribute('src')
url
# Out:
# 'https://scraping-for-beginner.herokuapp.com/static/assets/img/img1.JPG'

# %%
import io
from urllib import request

# %%
f = io.BytesIO(request.urlopen(url).read())

# %%
f

# %%
img = Image.open(f)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x798 at 0x1C6578FB4E0>

# %%
img.save('img01.jpg')

# %% [markdown]
# # すべての画像を収集

# %% [markdown]
# ## 1枚の画像取得の流れ

# %%
elem = browser.find_element_by_class_name('material-placeholder')
elem =elem.find_element_by_tag_name('img')

url = elem.get_attribute('src')

f = io.BytesIO(request.urlopen(url).read())
img = Image.open(f)
img.save('img01.jpg')

# %%
elems = browser.find_elements_by_class_name('material-placeholder')

for index, elem in enumerate(elems):
    elem =elem.find_element_by_tag_name('img')

    url = elem.get_attribute('src')

    f = io.BytesIO(request.urlopen(url).read())
    img = Image.open(f)
    img.save('image/img{}.jpg'.format(index))

# %%
xpath = '/html/body/div[2]/div/div/div[1]/ul/li[1]'

# %%
browser.find_element_by_xpath(xpath).text
# Out:
# 'check ログイン'
